# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r"./datafiles/Wellbore_development_all_08oct2019.xlsx",sheet_name='wellbore_development_all')

# %%
data.head()
# Out:
#   Wellbore name Well name  Drilling operator Drilled in production licence  \
# 0     1/3-A-1 H   1/3-A-1  DONG E&P Norge AS                          274
# 1     1/3-A-2 H   1/3-A-2  DONG E&P Norge AS                          274
# 2     1/3-A-3 H   1/3-A-3  DONG E&P Norge AS                          274
# 3       1/3-K-1   1/3-K-1  BP Amoco Norge AS                          065
# 4       1/3-K-2   1/3-K-2        Aker BP ASA                          065
#
#       Status      Purpose Purpose - planned         Content         Type  \
# 0     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 1     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 2     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 3  PRODUCING   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 4    PLUGGED  OBSERVATION        PRODUCTION  NOT APPLICABLE  DEVELOPMENT
#
#   Subsea  ... Publication date Release date  \
# ...

# %%
data.columns
# Out:
# Index(['Wellbore name', 'Well name', 'Drilling operator',
#        'Drilled in production licence', 'Status', 'Purpose',
#        'Purpose - planned', 'Content', 'Type', 'Subsea', 'Entered date',
#        'Completed date', 'Predrilled entry date', 'Predrilled completion date',
#        'Field', 'Drill permit', 'Discovery', 'Discovery wellbore',
#        'Kelly bushing elevation [m]', 'Final vertical depth (TVD) [m RKB]',
#        'Total depth (MD) [m RKB]', 'Water depth [m]',
#        'Kick off  point [m RKB]', 'Main area', 'Drilling facility',
#        'Drilling facility type', 'Drilling facility category',
#        'Production facility', 'Licensing activity awarded in', 'Multilateral',
#        'Content - planned', 'Entry year', 'Completed year',
#        'Reclassified from/to wellbore', 'Plugged and abondon date',
#        'Plugged date', 'Prod. licence for drilling target', 'Plot symbol',
#        'Geodetic datum', 'NS degrees', 'NS minutes', 'NS seconds', 'NS code',
# ...

# %%
filtered=['Wellbore name','Drilling operator','Purpose','Entered date','Completed date']
data[filtered].head()
# Out:
#   Wellbore name  Drilling operator      Purpose Entered date Completed date
# 0     1/3-A-1 H  DONG E&P Norge AS   PRODUCTION   2011-07-22     2011-09-21
# 1     1/3-A-2 H  DONG E&P Norge AS   PRODUCTION   2011-11-18     2012-01-19
# 2     1/3-A-3 H  DONG E&P Norge AS   PRODUCTION   2012-03-04     2012-05-14
# 3       1/3-K-1  BP Amoco Norge AS   PRODUCTION   1998-05-08     1998-07-31
# 4       1/3-K-2        Aker BP ASA  OBSERVATION   2018-01-02     2018-01-19

# %%
data[filtered].sort_values(by='Completed date',ascending=True).head()
# Out:
#     Wellbore name                  Drilling operator     Purpose Entered date  \
# 120      2/4-A-92  Phillips Petroleum Company Norway  PRODUCTION   1969-09-18
# 121      2/4-A-93  Phillips Petroleum Company Norway  PRODUCTION   1970-01-27
# 122      2/4-A-94  Phillips Petroleum Company Norway  PRODUCTION   1970-06-02
# 123      2/4-A-95  Phillips Petroleum Company Norway  PRODUCTION   1970-06-21
# 105      2/4-A-13  Phillips Petroleum Company Norway  PRODUCTION   1973-11-13
#
#     Completed date
# 120     1969-12-24
# 121     1970-05-31
# 122     1970-08-01
# 123     1970-08-27
# 105     1974-04-24

# %%
data[filtered].dtypes

# Here is where we can get the first big problem
#from datetime import datetime
#datetime_object = datetime.strptime('12/23/2009', '%m/%d/%Y')
#print(datetime_object)
# Out:
# Wellbore name                object
# Drilling operator            object
# Purpose                      object
# Entered date         datetime64[ns]
# Completed date       datetime64[ns]
# dtype: object

# %% [markdown]
# # Calculation on rows

# %%
data['TotalTime']=data['Completed date']-data['Entered date']
data['TTnum']=data['TotalTime'].dt.days
data.head()
#data['TotalTimeAbs']=data['TotalTime'].apply(abs)
#filtered.append('TotalTimeAbs')
# Out:
#   Wellbore name Well name  Drilling operator Drilled in production licence  \
# 0     1/3-A-1 H   1/3-A-1  DONG E&P Norge AS                          274
# 1     1/3-A-2 H   1/3-A-2  DONG E&P Norge AS                          274
# 2     1/3-A-3 H   1/3-A-3  DONG E&P Norge AS                          274
# 3       1/3-K-1   1/3-K-1  BP Amoco Norge AS                          065
# 4       1/3-K-2   1/3-K-2        Aker BP ASA                          065
#
#       Status      Purpose Purpose - planned         Content         Type  \
# 0     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 1     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 2     CLOSED   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 3  PRODUCING   PRODUCTION        PRODUCTION             OIL  DEVELOPMENT
# 4    PLUGGED  OBSERVATION        PRODUCTION  NOT APPLICABLE  DEVELOPMENT
#
#   Subsea  ... NPDID production licence drilled in  \
# ...

# %% [markdown]
# # Aggregation

# %%
f2=['Drilling operator','Purpose','TTnum']
grouped=data.groupby(by=['Drilling operator','Purpose','Content']).mean()
grouped.reset_index(inplace=True)
#print(grouped.dtypes)
grouped.head()
# Out:
#   Drilling operator      Purpose         Content  Kelly bushing elevation [m]  \
# 0  A/S Norske Shell    INJECTION             GAS                    25.000000
# 1  A/S Norske Shell    INJECTION           WATER                    25.000000
# 2  A/S Norske Shell  OBSERVATION             GAS                    36.000000
# 3  A/S Norske Shell  OBSERVATION  NOT APPLICABLE                    39.666667
# 4  A/S Norske Shell   PRODUCTION             GAS                    36.200000
#
#    Final vertical depth (TVD) [m RKB]  Total depth (MD) [m RKB]  \
# 0                                 NaN               2129.000000
# 1                                 NaN               2420.800000
# 2                                 NaN               3035.000000
# 3                                 NaN               2320.333333
# 4                                 NaN               3483.900000
#
#    Water depth [m]  Kick off  point [m RKB]   Entry year  Completed year  ...  \
# ...

# %%
import plotly.express as px
fig = px.bar(grouped, x="Drilling operator", y="TTnum",color='Purpose',width=800, height=800)
fig.show()
# Out:
# <div>                            <div id="73250f63-5b17-470e-a360-42b744da3508" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73250f63-5b17-470e-a360-42b744da3508")) {                    Plotly.newPlot(                        "73250f63-5b17-470e-a360-42b744da3508",                        [{"alignmentgroup": "True", "hovertemplate": "Purpose=INJECTION<br>Drilling operator=%{x}<br>TTnum=%{y}<extra></extra>", "legendgroup": "INJECTION", "marker": {"color": "#636efa"}, "name": "INJECTION", "offsetgroup": "INJECTION", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["A/S Norske Shell", "A/S Norske Shell", "Aker BP ASA", "Amoco Norway Oil Company", "BG Norge AS", "BP Amoco Norge AS", "BP Norge AS", "BP Norge AS", "BP
# ...

# %%
fig = px.sunburst(grouped.sample(25), path=['Drilling operator','Purpose', 'Content'], values='TTnum')
fig.show()
# Out:
# <div>                            <div id="44db44ff-7681-4e91-b73d-0e745bd81dab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44db44ff-7681-4e91-b73d-0e745bd81dab")) {                    Plotly.newPlot(                        "44db44ff-7681-4e91-b73d-0e745bd81dab",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>TTnum=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["ExxonMobil Exploration and Production Norway AS/INJECTION/CUTTINGS", "StatoilHydro ASA/INJECTION/CUTTINGS", "StatoilHydro Petroleum AS/PRODUCTION/DRY", "A/S Norske Shell/INJECTION/GAS", "Norsk Hydro Produksjon AS/INJECTION/GAS", "Statoil ASA (old)/PRODUCTION/GAS", "Total E&P Norge AS/
# ...

# %%
talisman=data.loc[(data['Drilling operator']=="Talisman Energy Norge AS")]
talisman.head()
# Out:
#    Wellbore name Well name         Drilling operator  \
# 31     2/1-A-2 A   2/1-A-2  Talisman Energy Norge AS
# 38     2/1-A-7 A   2/1-A-7  Talisman Energy Norge AS
# 42     2/1-A-9 A   2/1-A-9  Talisman Energy Norge AS
# 43      2/1-A-10  2/1-A-10  Talisman Energy Norge AS
# 50    2/1-A-14 C  2/1-A-14  Talisman Energy Norge AS
#
#    Drilled in production licence     Status     Purpose Purpose - planned  \
# 31                         019 B  PRODUCING  PRODUCTION        PRODUCTION
# 38                         019 B    PLUGGED  PRODUCTION        PRODUCTION
# 42                         019 B     CLOSED   INJECTION         INJECTION
# 43                         019 B     CLOSED  PRODUCTION        PRODUCTION
# 50                         019 B     CLOSED   INJECTION         INJECTION
#
#    Content         Type Subsea  ... NPDID production licence drilled in  \
# 31     OIL  DEVELOPMENT     NO  ...                             20924.0
# ...

# %%
fig = px.bar(talisman, x="Purpose", y="TTnum",color='Purpose',width=800, height=800)
fig.show()
# Out:
# <div>                            <div id="dd78dc92-d446-4bf6-9cff-7428ab71e4ed" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd78dc92-d446-4bf6-9cff-7428ab71e4ed")) {                    Plotly.newPlot(                        "dd78dc92-d446-4bf6-9cff-7428ab71e4ed",                        [{"alignmentgroup": "True", "hovertemplate": "Purpose=%{x}<br>TTnum=%{y}<extra></extra>", "legendgroup": "PRODUCTION", "marker": {"color": "#636efa"}, "name": "PRODUCTION", "offsetgroup": "PRODUCTION", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION", "PRODUCTION"
# ...

# %%
fig = px.scatter(data, x='Water depth [m]', y='TTnum')
fig.show()
# Out:
# <div>                            <div id="3b3abaa4-eddb-4058-a4ff-d11c37c68d55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b3abaa4-eddb-4058-a4ff-d11c37c68d55")) {                    Plotly.newPlot(                        "3b3abaa4-eddb-4058-a4ff-d11c37c68d55",                        [{"hovertemplate": "Water depth [m]=%{x}<br>TTnum=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [72.0, 72.0, 72.0, 68.0, 67.4, 67.4, 67.4, 67.4, 67.4, 67.4, 67.4, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 69.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 66.0, 66.0, 65.5, 66.0, 66.0, 66.0, 66.0, 66.0, 66.0, 65.5, 66.0, 65.5, 
# ...

# %%
subset=data[['Wellbore name','Drilling operator','TTnum','Purpose','Water depth [m]']]
final=subset.dropna()
fig = px.scatter(final, x="Water depth [m]", y="TTnum",color="Drilling operator", facet_col="Purpose")
fig.show()
# Out:
# <div>                            <div id="c645c79a-c0cc-45c5-b220-2ad13b3b6006" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c645c79a-c0cc-45c5-b220-2ad13b3b6006")) {                    Plotly.newPlot(                        "c645c79a-c0cc-45c5-b220-2ad13b3b6006",                        [{"hovertemplate": "Drilling operator=DONG E&P Norge AS<br>Purpose=PRODUCTION<br>Water depth [m]=%{x}<br>TTnum=%{y}<extra></extra>", "legendgroup": "DONG E&P Norge AS", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "DONG E&P Norge AS", "showlegend": true, "type": "scattergl", "x": [72.0, 72.0, 72.0, 65.4, 65.0], "xaxis": "x", "y": [61.0, 62.0, 71.0, 29.0, 47.0], "yaxis": "y"}, {"hovertemplate": "Drilling operator=DONG E&P Norge AS<
# ...

# %%
new=data[data['TTnum']<100].sample(150)
fig = px.parallel_categories(new[['Drilling operator','Purpose','Content','TTnum']], color="TTnum", color_continuous_scale=px.colors.sequential.Inferno)
fig.show()
# Out:
# <div>                            <div id="51de1eb2-ea3f-4da9-bd78-fb0e335db9ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51de1eb2-ea3f-4da9-bd78-fb0e335db9ca")) {                    Plotly.newPlot(                        "51de1eb2-ea3f-4da9-bd78-fb0e335db9ca",                        [{"dimensions": [{"label": "Drilling operator", "values": ["Statoil Petroleum AS", "Norsk Hydro Produksjon AS", "Den norske stats oljeselskap a.s", "ConocoPhillips Skandinavia AS", "Statoil ASA (old)", "Equinor Energy AS", "Norsk Hydro Produksjon AS", "Statoil Petroleum AS", "Phillips Petroleum Company Norway", "Phillips Petroleum Company Norway", "Norsk Hydro Produksjon AS", "Den norske stats oljeselskap a.s", "Statoil ASA (old)", "Norsk Hydro Produksjon AS", "De
# ...
